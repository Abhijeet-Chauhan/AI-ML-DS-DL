# %%
corpus = """Hello welcome, to Abhijeet's world.
This is a test sentence!It contains multiple lines.
"""

# %%
corpus
# Out:
# "Hello welcome, to Abhijeet's world.\nThis is a test sentence!\nIt contains multiple lines.\n"

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhij\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
## Tokenization
#sentence to paragraph
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
## Tokenization
# Paragraph to words
# sentence to words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Abhijeet',
#  "'s",
#  'world',
#  '.',
#  'This',
#  'is',
#  'a',
#  'test',
#  'sentence',
#  '!',
#  'It',
#  'contains',
#  'multiple',
#  'lines',
#  '.']

# %%
for sentence in documents:
    print("Sentence:", sentence)
    words = word_tokenize(sentence)
    print("Words:", words)
# Out:
# Sentence: Hello welcome, to Abhijeet's world.
# Words: ['Hello', 'welcome', ',', 'to', 'Abhijeet', "'s", 'world', '.']
# Sentence: This is a test sentence!
# Words: ['This', 'is', 'a', 'test', 'sentence', '!']
# Sentence: It contains multiple lines.
# Words: ['It', 'contains', 'multiple', 'lines', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Abhijeet',
#  "'",
#  's',
#  'world',
#  '.',
#  'This',
#  'is',
#  'a',
#  'test',
#  'sentence',
#  '!',
#  'It',
#  'contains',
#  'multiple',
#  'lines',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
TreebankWordTokenizer = TreebankWordTokenizer()

# %%
tokenized = TreebankWordTokenizer.tokenize(corpus)

# %%
tokenized
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Abhijeet',
#  "'s",
#  'world.',
#  'This',
#  'is',
#  'a',
#  'test',
#  'sentence',
#  '!',
#  'It',
#  'contains',
#  'multiple',
#  'lines',
#  '.']
